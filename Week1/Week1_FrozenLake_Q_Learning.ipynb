# %% [markdown]
# # Week 1: Q-Learning on FrozenLake

# %% [markdown]
# Welcome to Week 1! This week we’ll get hands-on with **Q-learning** using OpenAI Gym’s **FrozenLake-v1** environment. Your goal is to train a tabular Q-learning agent to navigate a slippery frozen lake without falling into holes.

# %% [markdown]
# Read about the FrozenLake environment from the openAI gymnasium website and try to solve this assignment

# %% [markdown]
# ## Goals

# %% [markdown]
# - Understand and implement Q-learning with a Q-table.
# - Use an ε-greedy exploration strategy.
# - Visualize training progress with reward curves.
# - Evaluate the learned policy.

# %% [markdown]
# ## Environment Setup

# %%
# !pip install gym==0.26.2 matplotlib numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gym==0.26.2 in /Users/hp/Library/Python/3.9/lib/python/site-packages (0.26.2)
# Requirement already satisfied: matplotlib in /Users/hp/Library/Python/3.9/lib/python/site-packages (3.9.4)
# Requirement already satisfied: numpy in /Users/hp/Library/Python/3.9/lib/python/site-packages (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/hp/Library/Python/3.9/lib/python/site-packages (from gym==0.26.2) (3.1.1)
# Requirement already satisfied: importlib_metadata>=4.8.0 in /Users/hp/Library/Python/3.9/lib/python/site-packages (from gym==0.26.2) (8.7.0)
# Requirement already satisfied: gym_notices>=0.0.4 in /Users/hp/Library/Python/3.9/lib/python/site-packages (from gym==0.26.2) (0.0.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/hp/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/hp/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/hp/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/hp/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/hp/Library/Python/3.9/lib/python/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/hp/Library/Python/3.9/lib/python/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/hp/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/hp/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/hp/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.20 in /Users/hp/Library/Python/3.9/lib/python/site-packages (from importlib_metadata>=4.8.0->gym==0.26.2) (3.23.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)

# %%
import gym
import numpy as np
import matplotlib.pyplot as plt

env = gym.make("FrozenLake-v1", is_slippery=True, render_mode="rgb_array")
state_space_size = env.observation_space.n
action_space_size = env.action_space.n
Q = np.zeros((state_space_size, action_space_size))

# %% [markdown]
# ## Training Loop
# Complete the training loop

# %%
def train_agent(episodes=2000, alpha=0.8, gamma=0.95, epsilon=1.0, decay=0.995):
    rewards = []
    for ep in range(episodes):
        state = env.reset()[0]
        done = False
        total_reward = 0
        while not done:
            #TODO select action
            if np.random.uniform(0,1) > epsilon : 
                action = env.action_space.sample() 
            else : 
                action = np.argmax(Q[state])
            next_state, reward, done, _, _ = env.step(action) #uncomment this after adding algo to choose action
            
            #TODO Update The Q values
            Q[state, action] = Q[state, action] + alpha * (
                reward + gamma * np.max(Q[next_state]) - Q[state, action]
            )
            state = next_state
            total_reward += reward
        #TODO maybe try decaying epsilon between episodes
        epsilon *= decay 
        rewards.append(total_reward)
    return rewards

# %% [markdown]
# ## Plotting Results

# %%
rewards = train_agent()
plt.plot(np.convolve(rewards, np.ones(100)/100, mode='valid'))
plt.title("100-Episode Moving Average of Rewards")
plt.xlabel("Episode")
plt.ylabel("Average Reward")
plt.show()

# %% [markdown]
# ## Test the Learned Policy

# %%
def test_agent(Q, episodes=5):
    for ep in range(episodes):
        state = env.reset()[0]
        done = False
        print(f"Episode {ep + 1}")
        while not done:
            action = np.argmax(Q[state])
            next_state, reward, done, _, _ = env.step(action)
            env.render()
            state = next_state

# %%
# !pip install pygame
test_agent(Q)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pygame
#   Using cached pygame-2.6.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (12 kB)
# Using cached pygame-2.6.1-cp39-cp39-macosx_11_0_arm64.whl (12.4 MB)
# Installing collected packages: pygame
# Successfully installed pygame-2.6.1
# Episode 1
# Episode 2
# Episode 3
# Episode 4
# Episode 5

# %% [markdown]
# ## Challenges

# %% [markdown]
# 1. Set `is_slippery=False` and compare performance.
# 2. Change the reward for falling into holes.
# 3. Add a decaying learning rate `α = α0 / (1 + decay * t)`.
# 4. Visualize the Q-table as a heatmap (optional).
# 5. Maybe try to think about how to generalize this to solve a random lake without pretraining on the specific environment(Post your ideas on the whatsapp group and we will host a competition if people are interested)

# %% [markdown]
# ## TLDR

# %% [markdown]
# Learn how to implement tabular Q-learning to solve a simple environment. Use exploration, value updates, and reward tracking to build intuition before moving to deep RL.
